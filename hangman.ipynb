# %%
word = "Drishti"

guessed = ""
chances = 6

print("Ayush ka game")
while chances>0:
    display = ""
    for letter in word:
        if letter in guessed:
            display += letter

        else:
            display += "-"

    print("word" , display)
    if display == word:
        print("You win")
        break

    guess = input("guess a letter: ")
    guessed += guess
    
    if guess not in word:
        print("you win")
        break

    guess = input("Guess a letter: " )
    guessed += guess

    if guess not in word:
        chance -= 1
        print("wrong guess")
        print("chances left:", chances)

if chances == 0:
    print("you lost")
    print("Word was", word)
# Out:
# Ayush ka game
# word -------
# guess a letter:  d
# you win
